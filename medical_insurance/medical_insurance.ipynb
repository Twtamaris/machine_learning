# %% [markdown]
# # Part1: Data Preprocessing

# %% [markdown]
# ## Importing the libraries and Dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv("Medicalpremium.csv")

# %% [markdown]
# ## Data Exploration

# %%
dataset.head()
# Out:
#    Age  Diabetes  BloodPressureProblems  AnyTransplants  AnyChronicDiseases  \
# 0   45         0                      0               0                   0
# 1   60         1                      0               0                   0
# 2   36         1                      1               0                   0
# 3   52         1                      1               0                   1
# 4   38         0                      0               0                   1
#
#    Height  Weight  KnownAllergies  HistoryOfCancerInFamily  \
# 0     155      57               0                        0
# 1     180      73               0                        0
# 2     158      59               0                        0
# 3     183      93               0                        0
# 4     166      88               0                        0
#
#    NumberOfMajorSurgeries  PremiumPrice
# 0                       0         25000
# 1                       0         29000
# ...

# %%
dataset.shape
# Out:
# (986, 11)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 986 entries, 0 to 985
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      986 non-null    int64
#  1   Diabetes                 986 non-null    int64
#  2   BloodPressureProblems    986 non-null    int64
#  3   AnyTransplants           986 non-null    int64
#  4   AnyChronicDiseases       986 non-null    int64
#  5   Height                   986 non-null    int64
#  6   Weight                   986 non-null    int64
#  7   KnownAllergies           986 non-null    int64
#  8   HistoryOfCancerInFamily  986 non-null    int64
#  9   NumberOfMajorSurgeries   986 non-null    int64
#  10  PremiumPrice             986 non-null    int64
# dtypes: int64(11)
# memory usage: 84.9 KB

# %%
dataset.select_dtypes(include='object').columns
# Out:
# Index([], dtype='object')

# %%
dataset.select_dtypes(include=['int64']).columns
# Out:
# Index(['Age', 'Diabetes', 'BloodPressureProblems', 'AnyTransplants',
#        'AnyChronicDiseases', 'Height', 'Weight', 'KnownAllergies',
#        'HistoryOfCancerInFamily', 'NumberOfMajorSurgeries', 'PremiumPrice'],
#       dtype='object')

# %%
len(dataset.select_dtypes(include=['int64']).columns)
# Out:
# 11

# %%
# Statical Summary
dataset.describe()
# Out:
#               Age    Diabetes  BloodPressureProblems  AnyTransplants  \
# count  986.000000  986.000000             986.000000      986.000000
# mean    41.745436    0.419878               0.468560        0.055781
# std     13.963371    0.493789               0.499264        0.229615
# min     18.000000    0.000000               0.000000        0.000000
# 25%     30.000000    0.000000               0.000000        0.000000
# 50%     42.000000    0.000000               0.000000        0.000000
# 75%     53.000000    1.000000               1.000000        0.000000
# max     66.000000    1.000000               1.000000        1.000000
#
#        AnyChronicDiseases      Height      Weight  KnownAllergies  \
# count          986.000000  986.000000  986.000000      986.000000
# mean             0.180527  168.182556   76.950304        0.215010
# std              0.384821   10.098155   14.265096        0.411038
# min              0.000000  145.000000   51.000000        0.000000
# ...

# %%
dataset.head()
# Out:
#    Age  Diabetes  BloodPressureProblems  AnyTransplants  AnyChronicDiseases  \
# 0   45         0                      0               0                   0
# 1   60         1                      0               0                   0
# 2   36         1                      1               0                   0
# 3   52         1                      1               0                   1
# 4   38         0                      0               0                   1
#
#    Height  Weight  KnownAllergies  HistoryOfCancerInFamily  \
# 0     155      57               0                        0
# 1     180      73               0                        0
# 2     158      59               0                        0
# 3     183      93               0                        0
# 4     166      88               0                        0
#
#    NumberOfMajorSurgeries  PremiumPrice
# 0                       0         25000
# 1                       0         29000
# ...

# %% [markdown]
# Grooup the dataset by 'sex', 'smoker', 'region'

# %%
dataset.groupby('Diabetes').mean()
# Out:
#                 Age  BloodPressureProblems  AnyTransplants  \
# Diabetes
# 0         39.241259               0.414336        0.062937
# 1         45.205314               0.543478        0.045894
#
#           AnyChronicDiseases      Height     Weight  KnownAllergies  \
# Diabetes
# 0                   0.209790  168.215035  77.248252        0.243007
# 1                   0.140097  168.137681  76.538647        0.176329
#
#           HistoryOfCancerInFamily  NumberOfMajorSurgeries  PremiumPrice
# Diabetes
# 0                        0.132867                0.589161  23931.818182
# 1                        0.096618                0.775362  24896.135266

# %%
dataset.groupby('BloodPressureProblems').mean()
# Out:
#                              Age  Diabetes  AnyTransplants  \
# BloodPressureProblems
# 0                      38.536260  0.360687        0.061069
# 1                      45.385281  0.487013        0.049784
#
#                        AnyChronicDiseases      Height     Weight  \
# BloodPressureProblems
# 0                                0.164122  168.541985  77.767176
# 1                                0.199134  167.774892  76.023810
#
#                        KnownAllergies  HistoryOfCancerInFamily  \
# BloodPressureProblems
# 0                            0.219466                 0.103053
# 1                            0.209957                 0.134199
#
#                        NumberOfMajorSurgeries  PremiumPrice
# BloodPressureProblems
# 0                                    0.490458  23356.870229
# 1                                    0.867965  25448.051948

# %%
dataset.groupby('NumberOfMajorSurgeries').mean()
# Out:
#                               Age  Diabetes  BloodPressureProblems  \
# NumberOfMajorSurgeries
# 0                       37.851775  0.411273               0.342380
# 1                       40.819892  0.344086               0.537634
# 2                       57.386555  0.621849               0.781513
# 3                       63.500000  0.937500               0.312500
#
#                         AnyTransplants  AnyChronicDiseases      Height  \
# NumberOfMajorSurgeries
# 0                             0.054280            0.173278  167.839248
# 1                             0.061828            0.180108  168.397849
# 2                             0.042017            0.235294  168.647059
# 3                             0.062500            0.000000  170.000000
#
#                            Weight  KnownAllergies  HistoryOfCancerInFamily  \
# NumberOfMajorSurgeries
# 0                       77.283925        0.110647                  0.00000
# ...

# %%
dataset.groupby('HistoryOfCancerInFamily').mean()
# Out:
#                                Age  Diabetes  BloodPressureProblems  \
# HistoryOfCancerInFamily
# 0                        41.886207  0.429885               0.459770
# 1                        40.689655  0.344828               0.534483
#
#                          AnyTransplants  AnyChronicDiseases      Height  \
# HistoryOfCancerInFamily
# 0                              0.057471            0.179310  168.143678
# 1                              0.043103            0.189655  168.474138
#
#                             Weight  KnownAllergies  NumberOfMajorSurgeries  \
# HistoryOfCancerInFamily
# 0                        76.932184        0.197701                0.609195
# 1                        77.086207        0.344828                1.103448
#
#                          PremiumPrice
# HistoryOfCancerInFamily
# 0                        24147.126437
# 1                        25758.620690

# %% [markdown]
# ## Dealing with the missing Values

# %%
# check for missing values
dataset.isnull().sum()
# Out:
# Age                        0
# Diabetes                   0
# BloodPressureProblems      0
# AnyTransplants             0
# AnyChronicDiseases         0
# Height                     0
# Weight                     0
# KnownAllergies             0
# HistoryOfCancerInFamily    0
# NumberOfMajorSurgeries     0
# PremiumPrice               0
# dtype: int64

# %% [markdown]
# ## Encode the categorical Data

# %%
dataset.select_dtypes(include='object').columns
# Out:
# Index([], dtype='object')

# %%
dataset['AnyTransplants'].unique()
# Out:
# array([0, 1], dtype=int64)

# %% [markdown]
# # One hot encoding

# %%
pd.get_dummies(data=dataset, drop_first=True)
# Out:
#      Age  Diabetes  BloodPressureProblems  AnyTransplants  AnyChronicDiseases  \
# 0     45         0                      0               0                   0
# 1     60         1                      0               0                   0
# 2     36         1                      1               0                   0
# 3     52         1                      1               0                   1
# 4     38         0                      0               0                   1
# ..   ...       ...                    ...             ...                 ...
# 981   18         0                      0               0                   0
# 982   64         1                      1               0                   0
# 983   56         0                      1               0                   0
# 984   47         1                      1               0                   0
# 985   21         0                      0               0                   0
#
# ...

# %%
dataset.head()
# Out:
#    Age  Diabetes  BloodPressureProblems  AnyTransplants  AnyChronicDiseases  \
# 0   45         0                      0               0                   0
# 1   60         1                      0               0                   0
# 2   36         1                      1               0                   0
# 3   52         1                      1               0                   1
# 4   38         0                      0               0                   1
#
#    Height  Weight  KnownAllergies  HistoryOfCancerInFamily  \
# 0     155      57               0                        0
# 1     180      73               0                        0
# 2     158      59               0                        0
# 3     183      93               0                        0
# 4     166      88               0                        0
#
#    NumberOfMajorSurgeries  PremiumPrice
# 0                       0         25000
# 1                       0         29000
# ...

# %%
dataset.shape
# Out:
# (986, 11)

# %% [markdown]
# ## Corelation Matrix

# %%
dataset_2 = dataset.drop(columns='PremiumPrice')

# %%
dataset_2.corrwith(dataset.PremiumPrice).plot.bar(
    figsize=(16,9),
    title='Correlation with Charges', rot= 90, grid=True
)
# Out:
# <AxesSubplot:title={'center':'Correlation with Charges'}>

# %%
corr = dataset.corr()
corr
# Out:
#                               Age  Diabetes  BloodPressureProblems  \
# Age                      1.000000  0.210908               0.244888
# Diabetes                 0.210908  1.000000               0.127727
# BloodPressureProblems    0.244888  0.127727               1.000000
# AnyTransplants          -0.008549 -0.036652              -0.024538
# AnyChronicDiseases       0.051072 -0.089428               0.045424
# Height                   0.039879 -0.003783              -0.037926
# Weight                  -0.018590 -0.024563              -0.061016
# KnownAllergies          -0.024416 -0.080102              -0.011550
# HistoryOfCancerInFamily -0.027623 -0.055527               0.048239
# NumberOfMajorSurgeries   0.429181  0.122722               0.251568
# PremiumPrice             0.697540  0.076209               0.167097
#
#                          AnyTransplants  AnyChronicDiseases    Height  \
# Age                           -0.008549            0.051072  0.039879
# ...

# %%
#heatmap
plt.figure(figsize=(20,20))
sns.heatmap(data=corr, annot=True,linewidths=0.2, fmt='.2f',cmap='coolwarm')
plt.show()

# %% [markdown]
# ## Splitting the Dataset

# %%
#matrix of features/ Independent variable
x = dataset.drop(columns='PremiumPrice')
x.head()
# Out:
#    Age  Diabetes  BloodPressureProblems  AnyTransplants  AnyChronicDiseases  \
# 0   45         0                      0               0                   0
# 1   60         1                      0               0                   0
# 2   36         1                      1               0                   0
# 3   52         1                      1               0                   1
# 4   38         0                      0               0                   1
#
#    Height  Weight  KnownAllergies  HistoryOfCancerInFamily  \
# 0     155      57               0                        0
# 1     180      73               0                        0
# 2     158      59               0                        0
# 3     183      93               0                        0
# 4     166      88               0                        0
#
#    NumberOfMajorSurgeries
# 0                       0
# 1                       0
# 2                       1
# 3                       2
# ...

# %%
y = dataset.PremiumPrice

# %%
# train_test_split
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.2, random_state = 0)

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((788, 10), (198, 10), (788,), (198,))

# %%
x_train.head(), y_train.head()
# Out:
# (     Age  Diabetes  BloodPressureProblems  AnyTransplants  AnyChronicDiseases  \
#  158   43         0                      0               0                   0
#  154   21         0                      0               0                   0
#  40    20         0                      1               0                   0
#  306   56         0                      0               0                   0
#  561   37         1                      1               0                   1
#
#       Height  Weight  KnownAllergies  HistoryOfCancerInFamily  \
#  158     158     121               0                        0
#  154     157     118               1                        0
#  40      163      68               0                        0
#  306     169      95               1                        0
#  561     180      94               0                        0
#
#       NumberOfMajorSurgeries
#  158                       0
#  154                       1
# ...

# %% [markdown]
# ## Feature Scaling

# %% [markdown]
# the StandardScaler, you can bring all features to a similar scale, typically with a mean of 0 and a standard deviation of 1. This normalization helps prevent certain features from dominating the learning algorithm due to their larger magnitudes

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# fit the scaler to the train set, it will learn the parameters
# sc.fit le sikxa x_train ko value haru kasto xa bhanera ani sc ma replace gardinxa
# example sc.mean_ le x_train ko mean value dinxa
sc.fit(x_train)

# transform the train and test set
x_train = sc.transform(x_train)
x_test = sc.transform(x_test)
x_train, x_test
# Out:
# (array([[ 0.10117471, -0.86666667, -0.93366695, ..., -0.53234164,
#          -0.3702501 , -0.88839899],
#         [-1.47188787, -0.86666667, -0.93366695, ...,  1.87849292,
#          -0.3702501 ,  0.46830334],
#         [-1.54339071, -0.86666667,  1.07104573, ..., -0.53234164,
#          -0.3702501 , -0.88839899],
#         ...,
#         [-0.04183098, -0.86666667, -0.93366695, ..., -0.53234164,
#          -0.3702501 , -0.88839899],
#         [-1.40038502, -0.86666667,  1.07104573, ..., -0.53234164,
#          -0.3702501 , -0.88839899],
#         [-1.25737933,  1.15384615, -0.93366695, ...,  1.87849292,
#           2.70087705,  0.46830334]]),
#  array([[-0.3993452 ,  1.15384615, -0.93366695, ..., -0.53234164,
#          -0.3702501 , -0.88839899],
#         [ 0.31568324,  1.15384615,  1.07104573, ...,  1.87849292,
#          -0.3702501 ,  0.46830334],
#         [ 1.31672307, -0.86666667,  1.07104573, ..., -0.53234164,
#          -0.3702501 ,  1.82500568],
#         ...,
# ...

# %%
sc.mean_
# tala ko -9.917 mean ho age ko mean ho sc.fit garepaxi
# Out:
# array([-4.05766791e-17, -9.01703979e-18, -2.02883395e-17, -1.63433846e-17,
#        -1.12712997e-17, -2.25425995e-17, -3.71952891e-17,  4.28309390e-17,
#         2.25425995e-17,  0.00000000e+00])

# %% [markdown]
# # Building the model

# %% [markdown]
# ## 1)Multiple Linear Models

# %%
from sklearn.linear_model import LinearRegression
regressor_lr = LinearRegression()
regressor_lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor_lr.predict(x_test)

# %%
from sklearn.metrics import r2_score
